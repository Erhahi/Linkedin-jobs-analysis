# %% [markdown]
# **Goal: Prepare a clean, unified dataset from multiple CSV files so we can use it for analysis and modeling**

# %% [markdown]
# **LOADING DATA SET**

# %%
#mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#list the directories
import os
os.listdir('/content/drive/My Drive/Project data set')
# Out:
# ['companies.csv',
#  'company_industries.csv',
#  'job_industries.csv',
#  'company_specialities.csv',
#  'employee_counts.csv',
#  'job_skills.csv',
#  'benefits.csv',
#  'industries.csv',
#  'salaries.csv',
#  'skills.csv',
#  'postings.csv']

# %%
#import library
import pandas as pd

# %%
#read the files
benefits = pd.read_csv('/content/drive/My Drive/Project data set/benefits.csv')
companies = pd.read_csv("/content/drive/My Drive/Project data set/companies.csv")
company_industries = pd.read_csv("/content/drive/My Drive/Project data set/company_industries.csv")
company_specialities = pd.read_csv("/content/drive/My Drive/Project data set/company_specialities.csv")
employee_count = pd.read_csv("/content/drive/My Drive/Project data set/employee_counts.csv")
job_industries = pd.read_csv("/content/drive/My Drive/Project data set/job_industries.csv")
job_skills = pd.read_csv("/content/drive/My Drive/Project data set/job_skills.csv")
salaries = pd.read_csv("/content/drive/My Drive/Project data set/salaries.csv")
skills = pd.read_csv("/content/drive/My Drive/Project data set/skills.csv")
industries = pd.read_csv("/content/drive/My Drive/Project data set/industries.csv")
postings = pd.read_csv("/content/drive/My Drive/Project data set/postings.csv")

# %% [markdown]
# **View each file**

# %%
benefits.head(2)
# Out:
#        job_id  inferred               type
# 0  3887473071         0  Medical insurance
# 1  3887473071         0   Vision insurance

# %%
companies.head(2)
# Out:
#    company_id           name  \
# 0        1009            IBM
# 1        1016  GE HealthCare
#
#                                          description  company_size state  \
# 0  At IBM, we do more than work. We create. We cr...           7.0    NY
# 1  Every day millions of people feel the impact o...           7.0     0
#
#   country              city zip_code                                address  \
# 0      US  Armonk, New York    10504  International Business Machines Corp.
# 1      US           Chicago        0                                      -
#
#                                              url
# 0           https://www.linkedin.com/company/ibm
# 1  https://www.linkedin.com/company/gehealthcare

# %%
company_industries.head(2)
# Out:
#    company_id                        industry
# 0      391906  Book and Periodical Publishing
# 1    22292832                    Construction

# %%
company_specialities.head(2)
# Out:
#    company_id              speciality
# 0    22292832      window replacement
# 1    22292832  patio door replacement

# %%
employee_count.head(2)
# Out:
#    company_id  employee_count  follower_count  time_recorded
# 0      391906             186           32508     1712346173
# 1    22292832             311            4471     1712346173

# %%
job_industries.head(2)
# Out:
#        job_id  industry_id
# 0  3884428798           82
# 1  3887473071           48

# %%
job_skills.head(2)
# Out:
#        job_id skill_abr
# 0  3884428798      MRKT
# 1  3884428798        PR

# %%
salaries.head(2)
# Out:
#    salary_id      job_id  max_salary  med_salary  min_salary pay_period  \
# 0          1  3884428798         NaN        20.0         NaN     HOURLY
# 1          2  3887470552        25.0         NaN        23.0     HOURLY
#
#   currency compensation_type
# 0      USD       BASE_SALARY
# 1      USD       BASE_SALARY

# %%
skills.head(2)
# Out:
#   skill_abr    skill_name
# 0       ART  Art/Creative
# 1      DSGN        Design

# %%
industries.head(2)
# Out:
#    industry_id                    industry_name
# 0            1  Defense and Space Manufacturing
# 1            3  Computer Hardware Manufacturing

# %%
postings.head(2)
# Out:
#     job_id           company_name                              title  \
# 0   921716  Corcoran Sawyer Smith              Marketing Coordinator
# 1  1829192                    NaN  Mental Health Therapist/Counselor
#
#                                          description  max_salary pay_period  \
# 0  Job descriptionA leading real estate firm in N...        20.0     HOURLY
# 1  At Aspen Therapy and Wellness , we are committ...        50.0     HOURLY
#
#            location  company_id  views  med_salary  ...  \
# 0     Princeton, NJ   2774458.0   20.0         NaN  ...
# 1  Fort Collins, CO         NaN    1.0         NaN  ...
#
#                                          skills_desc   listed_time  \
# 0  Requirements: \n\nWe are seeking a College or ...  1.713398e+12
# 1                                                NaN  1.712858e+12
#
#    posting_domain  sponsored  work_type currency compensation_type  \
# 0             NaN          0  FULL_TIME      USD       BASE_SALARY
# 1             NaN          0  FULL_TIME      USD       BASE_SALARY
#
#   normalized_salary  zip_code     fips
# 0           38480.0    8540.0  34021.0
# 1           83200.0   80521.0   8069.0
#
# [2 rows x 31 columns]

# %% [markdown]
# **Merge the files into one clean DataFrame**

# %%
# Merge postings with salaries
df = postings.merge(salaries, on="job_id", how="left")

# Merge with companies
df = df.merge(companies, on="company_id", how="left")

# Merge with job_skills
df = df.merge(job_skills, on= "job_id", how= "left")

# Merge with skills
df = df.merge(skills, on="skill_abr", how="left")

# %%
df.head(3)
# Out:
#     job_id           company_name                              title  \
# 0   921716  Corcoran Sawyer Smith              Marketing Coordinator
# 1   921716  Corcoran Sawyer Smith              Marketing Coordinator
# 2  1829192                    NaN  Mental Health Therapist/Counselor
#
#                                        description_x  max_salary_x  \
# 0  Job descriptionA leading real estate firm in N...          20.0
# 1  Job descriptionA leading real estate firm in N...          20.0
# 2  At Aspen Therapy and Wellness , we are committ...          50.0
#
#   pay_period_x          location  company_id  views  med_salary_x  ...  \
# 0       HOURLY     Princeton, NJ   2774458.0   20.0           NaN  ...
# 1       HOURLY     Princeton, NJ   2774458.0   20.0           NaN  ...
# 2       HOURLY  Fort Collins, CO         NaN    1.0           NaN  ...
#
#                                        description_y company_size  state  \
# 0  With years of experience helping local buyers ...          2.0     NJ
# 1  With years of experience helping local buyers ...          2.0     NJ
# 2                                                NaN          NaN    NaN
#
#    country         city zip_code_y           address  \
# 0       US  Jersey City      07302  242 Tenth Street
# 1       US  Jersey City      07302  242 Tenth Street
# 2      NaN          NaN        NaN               NaN
#
#                                                  url  skill_abr  \
# 0  https://www.linkedin.com/company/corcoran-sawy...       MRKT
# 1  https://www.linkedin.com/company/corcoran-sawy...       SALE
# 2                                                NaN       HCPR
#
#              skill_name
# 0             Marketing
# 1                 Sales
# 2  Health Care Provider
#
# [3 rows x 49 columns]

# %% [markdown]
# **Handle Duplicates and Clean Columns**

# %%
# Drop Duplicates
df.drop_duplicates(inplace=True)

# %%
df.describe(include="all").transpose()
# Out:
#                                count  unique  \
# job_id                      207531.0     NaN
# company_name                  204705   24428
# title                         207531   72521
# description_x                 207519  107827
# max_salary_x                 50764.0     NaN
# pay_period_x                   61100       5
# location                      207531    8526
# company_id                  204709.0     NaN
# views                       204630.0     NaN
# med_salary_x                 10336.0     NaN
# min_salary_x                 50764.0     NaN
# formatted_work_type           207531       7
# applies                      40337.0     NaN
# original_listed_time        207531.0     NaN
# remote_allowed               26777.0     NaN
# job_posting_url               207531  123849
# application_url               144848   84800
# application_type              207531       4
# expiry                      207531.0     NaN
# closed_time                   1437.0     NaN
# formatted_experience_level    159491       6
# skills_desc                     3806    2212
# listed_time                 207531.0     NaN
# posting_domain                137921    4443
# sponsored                   207531.0     NaN
# work_type                     207531       7
# currency_x                     61100       6
# compensation_type_x            61100       1
# normalized_salary            61100.0     NaN
# zip_code_x                  171196.0     NaN
# fips                        160289.0     NaN
# salary_id                    61100.0     NaN
# max_salary_y                 50764.0     NaN
# med_salary_y                 10336.0     NaN
# min_salary_y                 50764.0     NaN
# pay_period_y                   61100       5
# currency_y                     61100       6
# compensation_type_y            61100       1
# name                          204705   24428
# description_y                 202960   24164
# company_size                195612.0     NaN
# state                         204644     788
# country                       204708      81
# city                          204705    4124
# zip_code_y                    204247    7779
# address                       204631   19476
# url                           204708   24473
# skill_abr                     205778      35
# skill_name                    205778      35
#
#                                                                           top  \
# job_id                                                                    NaN
# company_name                                                  The Job Network
# title                                                           Sales Manager
# description_x               Position Summary: Our Sales Manager has managi...
# max_salary_x                                                              NaN
# pay_period_x                                                           YEARLY
# location                                                        United States
# company_id                                                                NaN
# views                                                                     NaN
# med_salary_x                                                              NaN
# min_salary_x                                                              NaN
# formatted_work_type                                                 Full-time
# applies                                                                   NaN
# original_listed_time                                                      NaN
# remote_allowed                                                            NaN
# job_posting_url             https://www.linkedin.com/jobs/view/3905336002/...
# application_url             https://app.dataannotation.tech/worker_signup?...
# application_type                                                 OffsiteApply
# expiry                                                                    NaN
# closed_time                                                               NaN
# formatted_experience_level                                   Mid-Senior level
# skills_desc                 This position requires the following skills: E...
# listed_time                                                               NaN
# posting_domain                                            www.click2apply.net
# sponsored                                                                 NaN
# work_type                                                           FULL_TIME
# currency_x                                                                USD
# compensation_type_x                                               BASE_SALARY
# normalized_salary                                                         NaN
# zip_code_x                                                                NaN
# fips                                                                      NaN
# salary_id                                                                 NaN
# max_salary_y                                                              NaN
# med_salary_y                                                              NaN
# min_salary_y                                                              NaN
# pay_period_y                                                           YEARLY
# currency_y                                                                USD
# compensation_type_y                                               BASE_SALARY
# name                                                          The Job Network
# description_y               TheJobNetwork is a leading recruitment adverti...
# company_size                                                              NaN
# state                                                                       0
# country                                                                    US
# city                                                                 New York
# zip_code_y                                                                  0
# address                                                                     0
# url                          https://www.linkedin.com/company/the-job-network
# skill_abr                                                                  IT
# skill_name                                             Information Technology
#
#                               freq                  mean               std  \
# job_id                         NaN     3896567388.836555   82970449.123986
# company_name                  1469                   NaN               NaN
# title                         1351                   NaN               NaN
# description_x                  948                   NaN               NaN
# max_salary_x                   NaN          96526.457333      758480.95656
# pay_period_x                 36355                   NaN               NaN
# location                     13788                   NaN               NaN
# company_id                     NaN        12285331.78382   25881513.460011
# views                          NaN             14.828857         84.973351
# med_salary_x                   NaN          20976.830088      48922.223238
# min_salary_x                   NaN           67776.09446     536643.666568
# formatted_work_type         167812                   NaN               NaN
# applies                        NaN             10.170513         27.160571
# original_listed_time           NaN   1713154922398.83252  487933269.139426
# remote_allowed                 NaN                   1.0               0.0
# job_posting_url                  3                   NaN               NaN
# application_url                609                   NaN               NaN
# application_type            141044                   NaN               NaN
# expiry                         NaN  1716237085706.092285  2365892907.24491
# closed_time                    NaN  1712983853528.183838  377782174.416342
# formatted_experience_level   68954                   NaN               NaN
# skills_desc                     28                   NaN               NaN
# listed_time                    NaN  1713209877547.566895  395796589.309698
# posting_domain                5184                   NaN               NaN
# sponsored                      NaN                   0.0               0.0
# work_type                   167812                   NaN               NaN
# currency_x                   61078                   NaN               NaN
# compensation_type_x          61100                   NaN               NaN
# normalized_salary              NaN         186340.626595    4367242.155342
# zip_code_x                     NaN          50613.914764      30300.126587
# fips                           NaN           28655.08363      16081.326333
# salary_id                      NaN          20548.017119       11653.90838
# max_salary_y                   NaN          96526.457333      758480.95656
# med_salary_y                   NaN          20976.830088      48922.223238
# min_salary_y                   NaN           67776.09446     536643.666568
# pay_period_y                 36355                   NaN               NaN
# currency_y                   61078                   NaN               NaN
# compensation_type_y          61100                   NaN               NaN
# name                          1469                   NaN               NaN
# description_y                 1469                   NaN               NaN
# company_size                   NaN              4.934288          2.070716
# state                        15145                   NaN               NaN
# country                     183223                   NaN               NaN
# city                         12177                   NaN               NaN
# zip_code_y                   20125                   NaN               NaN
# address                      23708                   NaN               NaN
# url                           1469                   NaN               NaN
# skill_abr                    25256                   NaN               NaN
# skill_name                   25256                   NaN               NaN
#
#                                         min              25%              50%  \
# job_id                             921716.0     3894869457.0     3902322128.0
# company_name                            NaN              NaN              NaN
# title                                   NaN              NaN              NaN
# description_x                           NaN              NaN              NaN
# max_salary_x                            1.0             51.0          85000.0
# pay_period_x                            NaN              NaN              NaN
# location                                NaN              NaN              NaN
# company_id                           1009.0          13542.0         217338.0
# views                                   1.0              3.0              4.0
# med_salary_x                            0.0            18.45             25.0
# min_salary_x                            1.0             40.0          65000.0
# formatted_work_type                     NaN              NaN              NaN
# applies                                 1.0              1.0              3.0
# original_listed_time        1701810533000.0  1712863872000.0  1713396790000.0
# remote_allowed                          1.0              1.0              1.0
# job_posting_url                         NaN              NaN              NaN
# application_url                         NaN              NaN              NaN
# application_type                        NaN              NaN              NaN
# expiry                      1712903448000.0  1715483095000.0  1716043202000.0
# closed_time                 1712345932000.0  1712669768000.0  1712672097000.0
# formatted_experience_level              NaN              NaN              NaN
# skills_desc                             NaN              NaN              NaN
# listed_time                 1711317014000.0  1712888410000.0  1713408433000.0
# posting_domain                          NaN              NaN              NaN
# sponsored                               0.0              0.0              0.0
# work_type                               NaN              NaN              NaN
# currency_x                              NaN              NaN              NaN
# compensation_type_x                     NaN              NaN              NaN
# normalized_salary                       0.0          52000.0          81250.0
# zip_code_x                           1001.0          24149.0          48103.0
# fips                                 1003.0          13067.0          29183.0
# salary_id                               1.0         10576.75          20545.0
# max_salary_y                            1.0             51.0          85000.0
# med_salary_y                            0.0            18.45             25.0
# min_salary_y                            1.0             40.0          65000.0
# pay_period_y                            NaN              NaN              NaN
# currency_y                              NaN              NaN              NaN
# compensation_type_y                     NaN              NaN              NaN
# name                                    NaN              NaN              NaN
# description_y                           NaN              NaN              NaN
# company_size                            1.0              3.0              5.0
# state                                   NaN              NaN              NaN
# country                                 NaN              NaN              NaN
# city                                    NaN              NaN              NaN
# zip_code_y                              NaN              NaN              NaN
# address                                 NaN              NaN              NaN
# url                                     NaN              NaN              NaN
# skill_abr                               NaN              NaN              NaN
# skill_name                              NaN              NaN              NaN
#
#                                         75%              max
# job_id                         3904713527.5     3906267224.0
# company_name                            NaN              NaN
# title                                   NaN              NaN
# description_x                           NaN              NaN
# max_salary_x                       143100.0      120000000.0
# pay_period_x                            NaN              NaN
# location                                NaN              NaN
# company_id                        7801046.0      103472979.0
# views                                   8.0           9975.0
# med_salary_x                         2236.5         750000.0
# min_salary_x                       100000.0       85000000.0
# formatted_work_type                     NaN              NaN
# applies                                 8.0            967.0
# original_listed_time        1713478525000.0  1713572803000.0
# remote_allowed                          1.0              1.0
# job_posting_url                         NaN              NaN
# application_url                         NaN              NaN
# application_type                        NaN              NaN
# expiry                      1716088700000.0  1729124796000.0
# closed_time                 1713393421000.0  1713562107000.0
# formatted_experience_level              NaN              NaN
# skills_desc                             NaN              NaN
# listed_time                 1713485287000.0  1713572816000.0
# posting_domain                          NaN              NaN
# sponsored                               0.0              0.0
# work_type                               NaN              NaN
# currency_x                              NaN              NaN
# compensation_type_x                     NaN              NaN
# normalized_salary                  125000.0      535600000.0
# zip_code_x                          78201.0          99901.0
# fips                                42091.0          56045.0
# salary_id                           30488.0          40785.0
# max_salary_y                       143100.0      120000000.0
# med_salary_y                         2236.5         750000.0
# min_salary_y                       100000.0       85000000.0
# pay_period_y                            NaN              NaN
# currency_y                              NaN              NaN
# compensation_type_y                     NaN              NaN
# name                                    NaN              NaN
# description_y                           NaN              NaN
# company_size                            7.0              7.0
# state                                   NaN              NaN
# country                                 NaN              NaN
# city                                    NaN              NaN
# zip_code_y                              NaN              NaN
# address                                 NaN              NaN
# url                                     NaN              NaN
# skill_abr                               NaN              NaN
# skill_name                              NaN              NaN

# %%
# Drop irrelevant or redundant columns (like *_x and *_y)
df = df.drop(columns=[
    "max_salary_y", "med_salary_y", "min_salary_y","description_x", "description_y",
    "zip_code_y", "zip_code_x", "pay_period_y", "currency_y", "compensation_type_y"
])

# Rename columns with _x
data = df.rename(columns={
    "max_salary_x": "max_salary",
    "pay_period_x": "pay_period",
    "med_salary_x": "med_salary",
    "min_salary_x": "min_salary",
    "currency_x": "currency",
    "compensation_type_x": "compensation_type",
    "zip_code_x": "zip_code"
}, inplace= True)

# %%
df.head(2)
# Out:
#    job_id           company_name                  title  max_salary  \
# 0  921716  Corcoran Sawyer Smith  Marketing Coordinator        20.0
# 1  921716  Corcoran Sawyer Smith  Marketing Coordinator        20.0
#
#   pay_period       location  company_id  views  med_salary  min_salary  ...  \
# 0     HOURLY  Princeton, NJ   2774458.0   20.0         NaN        17.0  ...
# 1     HOURLY  Princeton, NJ   2774458.0   20.0         NaN        17.0  ...
#
#   salary_id                   name  company_size  state country         city  \
# 0   18531.0  Corcoran Sawyer Smith           2.0     NJ      US  Jersey City
# 1   18531.0  Corcoran Sawyer Smith           2.0     NJ      US  Jersey City
#
#             address                                                url  \
# 0  242 Tenth Street  https://www.linkedin.com/company/corcoran-sawy...
# 1  242 Tenth Street  https://www.linkedin.com/company/corcoran-sawy...
#
#    skill_abr skill_name
# 0       MRKT  Marketing
# 1       SALE      Sales
#
# [2 rows x 39 columns]

# %% [markdown]
# **Inspect and Clean Job Titles**- I was noticed that the salary was stated in the job title column, so I am going to inspect and clean

# %%
#Inspect Job Titles
suspicious_titles = df[df['title'].str.contains(r'\$|\d{2,}k|per year', case=False, na=False)]
suspicious_titles[['title', 'normalized_salary']]
# Out:
#                                                     title  normalized_salary
# 1423                     Mental Health Professional - $3,            73500.0
# 2553       Diesel Mechanic | Entry Level Technician | $3,                NaN
# 2554       Diesel Mechanic | Entry Level Technician | $3,                NaN
# 5468                              RN Registered Nurse $7,            92560.0
# 5526                              RN Registered Nurse $7,                NaN
# ...                                                   ...                ...
# 205396  Patient Financial Associate 1, ED Registration...                NaN
# 205565                      CONVENTIONAL DRIVER CDL-A $5,                NaN
# 205566                      CONVENTIONAL DRIVER CDL-A $5,                NaN
# 205912  Physical Therapist Oncology/Lymphedema, Outpat...                NaN
# 206299  Community Support Professional III - Intensive...            42214.0
#
# [818 rows x 2 columns]

# %%
import re

def clean_job_title(title):
    # Remove salary info like "$75k", "$20-$30/hour", "$3,000 Hiring Bonus"
    title = re.sub(r'\$[\d,]+(\.\d+)?([kK]?(\s*-\s*\$?[\d,]+[kK]?)?)?', '', title)

    # Remove words like "Hiring Bonus", "Sign on Bonus"
    title = re.sub(r'(?i)(hiring bonus|sign[- ]?on bonus|bonus)', '', title)

    # Remove emojis or non-ASCII characters
    title = title.encode('ascii', errors='ignore').decode()

    # Remove leftover punctuation and whitespace
    title = re.sub(r'[\(\)\[\]\{\}\-–—]+', ' ', title)
    title = re.sub(r'\s+', ' ', title).strip()
    return title

df['title'] = df['title'].apply(clean_job_title)

# %%
df.head(2)
# Out:
#    job_id           company_name                  title  max_salary  \
# 0  921716  Corcoran Sawyer Smith  Marketing Coordinator        20.0
# 1  921716  Corcoran Sawyer Smith  Marketing Coordinator        20.0
#
#   pay_period       location  company_id  views  med_salary  min_salary  ...  \
# 0     HOURLY  Princeton, NJ   2774458.0   20.0         NaN        17.0  ...
# 1     HOURLY  Princeton, NJ   2774458.0   20.0         NaN        17.0  ...
#
#   salary_id                   name  company_size  state country         city  \
# 0   18531.0  Corcoran Sawyer Smith           2.0     NJ      US  Jersey City
# 1   18531.0  Corcoran Sawyer Smith           2.0     NJ      US  Jersey City
#
#             address                                                url  \
# 0  242 Tenth Street  https://www.linkedin.com/company/corcoran-sawy...
# 1  242 Tenth Street  https://www.linkedin.com/company/corcoran-sawy...
#
#    skill_abr skill_name
# 0       MRKT  Marketing
# 1       SALE      Sales
#
# [2 rows x 39 columns]

# %% [markdown]
# **SAVE CLEAN DATA SET**

# %%
clean_path = "/content/drive/My Drive/Project data set/completed task/cleaned_linkedin_jobs.csv"
df.to_csv(clean_path, index=False)
